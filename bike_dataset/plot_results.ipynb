# %%
# Importing all necessary libraries
import matplotlib.pyplot as plt
import json

# %%
def read_barcode_data(barcode_json_path: str) -> list:
    ''' 
    Возращает данные из JSON, рассортированные по слоям нейросети
    Параметры:
    barcode_json_path - путь к файлу с данными
    Ответ:
    layer1, ..., layer6 - шесть списков с данными по каждому слою
    '''
    with open(barcode_json_path, 'r') as data:
        barcodes = json.load(data)

    layer1, layer2, layer3, layer4, layer5, layer6 = list(), list(), list(), list(), list(), list()

    for epoch in list(barcodes.keys()):
        layer1.append(barcodes[epoch]['layer1'])
        layer2.append(barcodes[epoch]['layer2'])
        layer3.append(barcodes[epoch]['layer3'])
        layer4.append(barcodes[epoch]['layer4'])
        layer5.append(barcodes[epoch]['layer5'])
        layer6.append(barcodes[epoch]['layer6'])

    return layer1, layer2, layer3, layer4, layer5, layer6

# %%
# Sort the data with each layer
layer1_3k, layer2_3k, layer3_3k, layer4_3k, layer5_3k, layer6_3k = read_barcode_data(barcode_json_path='/Users/pavelvavilov/Desktop/Topology_in_Neural_Networks/bike_dataset/bike_output/exp_0/weights_graphs_mlp_DataAmount3000/barcodes/barcode_data.json')
layer1_6k, layer2_6k, layer3_6k, layer4_6k, layer5_6k, layer6_6k = read_barcode_data(barcode_json_path='/Users/pavelvavilov/Desktop/Topology_in_Neural_Networks/bike_dataset/bike_output/exp_0/weights_graphs_mlp_DataAmount6000/barcodes/barcode_data.json')
layer1_9k, layer2_9k, layer3_9k, layer4_9k, layer5_9k, layer6_9k = read_barcode_data(barcode_json_path='/Users/pavelvavilov/Desktop/Topology_in_Neural_Networks/bike_dataset/bike_output/exp_0/weights_graphs_mlp_DataAmount9000/barcodes/barcode_data.json')
layer1_12k, layer2_12k, layer3_12k, layer4_12k, layer5_12k, layer6_12k = read_barcode_data(barcode_json_path='/Users/pavelvavilov/Desktop/Topology_in_Neural_Networks/bike_dataset/bike_output/exp_0/weights_graphs_mlp_DataAmount12000/barcodes/barcode_data.json')
layer1_15k, layer2_15k, layer3_15k, layer4_15k, layer5_15k, layer6_15k = read_barcode_data(barcode_json_path='/Users/pavelvavilov/Desktop/Topology_in_Neural_Networks/bike_dataset/bike_output/exp_0/weights_graphs_mlp_DataAmount15000/barcodes/barcode_data.json')
layer1_17k, layer2_17k, layer3_17k, layer4_17k, layer5_17k, layer6_17k = read_barcode_data(barcode_json_path='/Users/pavelvavilov/Desktop/Topology_in_Neural_Networks/bike_dataset/bike_output/exp_0/weights_graphs_mlp_DataAmount17379/barcodes/barcode_data.json')

# %%
print(layer1_3k)
# Out:
# [{'H0': [[0.0, 0.3448396325111389], [0.0, 0.6069158911705017], [0.0, 1.021215796470642], [0.0, 1.0350054502487183], [0.0, 1.0894734859466553], [0.0, 1.1979786157608032], [0.0, 1.3173233270645142], [0.0, 1.3496544361114502], [0.0, 1.385277509689331], [0.0, 1.3943606615066528], [0.0, 1.5036226511001587], [0.0, 1.6041439771652222], [0.0, 1.6688640117645264], [0.0, 1.7147080898284912], [0.0, 1.7314563989639282], [0.0, 1.7486140727996826], [0.0, 1.8581483364105225], [0.0, 1.860859990119934], [0.0, 1.9131394624710083], [0.0, 1.940649151802063], [0.0, 1.9484130144119263], [0.0, 2.026996612548828], [0.0, 2.0697906017303467], [0.0, 2.0748138427734375], [0.0, 2.0978949069976807], [0.0, 2.124492645263672], [0.0, 2.1290841102600098], [0.0, 2.203561782836914], [0.0, 2.2045302391052246], [0.0, 2.252058982849121], [0.0, 2.2576866149902344], [0.0, 2.2608325481414795], [0.0, 2.287010908126831], [0.0, 2.3306727409362793], [0.0, 2.370849609375], [0.0, 2.3995561599731445], [0.0, 2.4243204593658447], [0.
# ...

# %%
def calculate_homology_mean_lifetime(layer: list) -> int:
    ''' 
    
    '''
    last_epoch = layer[-1]['H0']
    lifetime = 0

    for i in range(len(last_epoch)):
        mean = (last_epoch[i][0] + last_epoch[i][1]) / 2
        lifetime += mean 

    mean_lifetime = lifetime / len(layer)

    return mean_lifetime

# %%
# Calculate the mean lifetime of the homologies in each layer for each amount of data
mean_lifetime_1_3k = calculate_homology_mean_lifetime(layer1_3k)
mean_lifetime_1_6k = calculate_homology_mean_lifetime(layer1_6k)
mean_lifetime_1_9k = calculate_homology_mean_lifetime(layer1_9k)
mean_lifetime_1_12k = calculate_homology_mean_lifetime(layer1_12k)
mean_lifetime_1_15k = calculate_homology_mean_lifetime(layer1_15k)
mean_lifetime_1_17k = calculate_homology_mean_lifetime(layer1_17k)
mean_lifetime_2_3k = calculate_homology_mean_lifetime(layer2_3k)
mean_lifetime_2_6k = calculate_homology_mean_lifetime(layer2_6k)
mean_lifetime_2_9k = calculate_homology_mean_lifetime(layer2_9k)
mean_lifetime_2_12k = calculate_homology_mean_lifetime(layer2_12k)
mean_lifetime_2_15k = calculate_homology_mean_lifetime(layer2_15k)
mean_lifetime_2_17k = calculate_homology_mean_lifetime(layer2_17k)
mean_lifetime_3_3k = calculate_homology_mean_lifetime(layer3_3k)
mean_lifetime_3_6k = calculate_homology_mean_lifetime(layer3_6k)
mean_lifetime_3_9k = calculate_homology_mean_lifetime(layer3_9k)
mean_lifetime_3_12k = calculate_homology_mean_lifetime(layer3_12k)
mean_lifetime_3_15k = calculate_homology_mean_lifetime(layer3_15k)
mean_lifetime_3_17k = calculate_homology_mean_lifetime(layer3_17k)
mean_lifetime_4_3k = calculate_homology_mean_lifetime(layer4_3k)
mean_lifetime_4_6k = calculate_homology_mean_lifetime(layer4_6k)
mean_lifetime_4_9k = calculate_homology_mean_lifetime(layer4_9k)
mean_lifetime_4_12k = calculate_homology_mean_lifetime(layer4_12k)
mean_lifetime_4_15k = calculate_homology_mean_lifetime(layer4_15k)
mean_lifetime_4_17k = calculate_homology_mean_lifetime(layer4_17k)
mean_lifetime_5_3k = calculate_homology_mean_lifetime(layer5_3k)
mean_lifetime_5_6k = calculate_homology_mean_lifetime(layer5_6k)
mean_lifetime_5_9k = calculate_homology_mean_lifetime(layer5_9k)
mean_lifetime_5_12k = calculate_homology_mean_lifetime(layer5_12k)
mean_lifetime_5_15k = calculate_homology_mean_lifetime(layer5_15k)
mean_lifetime_5_17k = calculate_homology_mean_lifetime(layer5_17k)
mean_lifetime_6_3k = calculate_homology_mean_lifetime(layer6_3k)
mean_lifetime_6_6k = calculate_homology_mean_lifetime(layer6_6k)
mean_lifetime_6_9k = calculate_homology_mean_lifetime(layer6_9k)
mean_lifetime_6_12k = calculate_homology_mean_lifetime(layer6_12k)
mean_lifetime_6_15k = calculate_homology_mean_lifetime(layer6_15k)
mean_lifetime_6_17k = calculate_homology_mean_lifetime(layer6_17k)

# %%
# Create a list with of amounts of data for this experiment
data_amounts = [3000, 6000, 9000, 12000, 15000, 17000]

# Create a total list of homologies lifetime through all data amounts
layer1_total = [mean_lifetime_1_3k, mean_lifetime_1_6k, mean_lifetime_1_9k, mean_lifetime_1_12k, mean_lifetime_1_15k, mean_lifetime_1_17k]
layer2_total = [mean_lifetime_2_3k, mean_lifetime_2_6k, mean_lifetime_2_9k, mean_lifetime_2_12k, mean_lifetime_2_15k, mean_lifetime_2_17k]
layer3_total = [mean_lifetime_3_3k, mean_lifetime_3_6k, mean_lifetime_3_9k, mean_lifetime_3_12k, mean_lifetime_3_15k, mean_lifetime_3_17k]
layer4_total = [mean_lifetime_4_3k, mean_lifetime_4_6k, mean_lifetime_4_9k, mean_lifetime_4_12k, mean_lifetime_4_15k, mean_lifetime_4_17k]
layer5_total = [mean_lifetime_5_3k, mean_lifetime_5_6k, mean_lifetime_5_9k, mean_lifetime_5_12k, mean_lifetime_5_15k, mean_lifetime_5_17k]
layer6_total = [mean_lifetime_6_3k, mean_lifetime_6_6k, mean_lifetime_6_9k, mean_lifetime_6_12k, mean_lifetime_6_15k, mean_lifetime_6_17k]

# %%
def plot_homologies_mean_lifetime_for_one_layer(mean_lifetime_value: float, data_amounts: list, layer_name: str) -> None:
    ''' 
    Build the graphs for data amounts and mean lifetime values
    Params:
    mean_lifetime_value - list of mean lifetime values
    data_amounts - list of data amounts for this experiment
    layer_name - name of a NNs hidden layer the graph belongs to
    Return:
    Graph for data amounts and mean lifetime values 
    '''
    plt.plot(data_amounts, mean_lifetime_value, marker='o')
    plt.title(layer_name)
    plt.xlabel('Data amounts')
    plt.ylabel('Mean lifetime')
    plt.grid(True)

    plt.show()

# %%
plot_homologies_mean_lifetime_for_one_layer(layer1_total, data_amounts, 'Layer 1')
plot_homologies_mean_lifetime_for_one_layer(layer2_total, data_amounts, 'Layer 2')
plot_homologies_mean_lifetime_for_one_layer(layer3_total, data_amounts, 'Layer 3')
plot_homologies_mean_lifetime_for_one_layer(layer4_total, data_amounts, 'Layer 4')
plot_homologies_mean_lifetime_for_one_layer(layer5_total, data_amounts, 'Layer 5')
plot_homologies_mean_lifetime_for_one_layer(layer6_total, data_amounts, 'Layer 6')
